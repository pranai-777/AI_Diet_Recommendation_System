# %%
# ==========================================================
# AI Diet Recommendation System
# Notebook 07 : Diet Recommendation Engine
# ==========================================================

print("❤️ AI Diet Recommendation System")
print("Notebook 07 : Diet Recommendation Engine")
# Out:
# ❤️ AI Diet Recommendation System
# Notebook 07 : Diet Recommendation Engine

# %%
# ==========================================================
# Import Libraries
# ==========================================================

import os
import pandas as pd

# %%
# ==========================================================
# Healthy Advice Database
# ==========================================================

DIET_ADVICE = {

    "banana": {
        "best_time": "Breakfast",
        "benefit": "Rich in potassium and natural energy.",
        "water": "Drink one glass of water.",
        "pair_with": "Oats or yogurt."
    },

    "milk": {
        "best_time": "Morning",
        "benefit": "Excellent source of calcium.",
        "water": "Drink water throughout the day.",
        "pair_with": "Oats or cereal."
    },

    "eggs": {
        "best_time": "Breakfast",
        "benefit": "High-quality protein.",
        "water": "Drink one glass of water.",
        "pair_with": "Whole wheat bread."
    },

    "chicken": {
        "best_time": "Lunch",
        "benefit": "Rich in lean protein.",
        "water": "Drink two glasses of water.",
        "pair_with": "Brown rice and vegetables."
    },

    "fish": {
        "best_time": "Lunch or Dinner",
        "benefit": "Rich in Omega-3 fatty acids.",
        "water": "Stay hydrated throughout the day.",
        "pair_with": "Steamed vegetables."
    }

}

print("Advice Database Loaded Successfully!")
# Out:
# Advice Database Loaded Successfully!

# %%
DIET_ADVICE
# Out:
# {'banana': {'best_time': 'Breakfast',
#   'benefit': 'Rich in potassium and natural energy.',
#   'water': 'Drink one glass of water.',
#   'pair_with': 'Oats or yogurt.'},
#  'milk': {'best_time': 'Morning',
#   'benefit': 'Excellent source of calcium.',
#   'water': 'Drink water throughout the day.',
#   'pair_with': 'Oats or cereal.'},
#  'eggs': {'best_time': 'Breakfast',
#   'benefit': 'High-quality protein.',
#   'water': 'Drink one glass of water.',
#   'pair_with': 'Whole wheat bread.'},
#  'chicken': {'best_time': 'Lunch',
#   'benefit': 'Rich in lean protein.',
#   'water': 'Drink two glasses of water.',
#   'pair_with': 'Brown rice and vegetables.'},
#  'fish': {'best_time': 'Lunch or Dinner',
#   'benefit': 'Rich in Omega-3 fatty acids.',
#   'water': 'Stay hydrated throughout the day.',
#   'pair_with': 'Steamed vegetables.'}}

# %%
# ==========================================================
# Diet Recommendation Function
# ==========================================================

def get_diet_recommendation(food_name):

    food_name = food_name.lower()

    if food_name in DIET_ADVICE:

        return DIET_ADVICE[food_name]

    return {

        "best_time": "Any Time",

        "benefit": "Healthy food choice.",

        "water": "Stay hydrated.",

        "pair_with": "Fresh vegetables."

    }

# %%
banana_advice = get_diet_recommendation("banana")

banana_advice
# Out:
# {'best_time': 'Breakfast',
#  'benefit': 'Rich in potassium and natural energy.',
#  'water': 'Drink one glass of water.',
#  'pair_with': 'Oats or yogurt.'}

# %%
print("=" * 60)
print("❤️ AI Diet Recommendation")
print("=" * 60)

print(f"🍽 Best Time : {banana_advice['best_time']}")
print(f"💪 Benefit   : {banana_advice['benefit']}")
print(f"💧 Water     : {banana_advice['water']}")
print(f"🥣 Eat With  : {banana_advice['pair_with']}")

print("=" * 60)
# Out:
# ============================================================
# ❤️ AI Diet Recommendation
# ============================================================
# 🍽 Best Time : Breakfast
# 💪 Benefit   : Rich in potassium and natural energy.
# 💧 Water     : Drink one glass of water.
# 🥣 Eat With  : Oats or yogurt.
# ============================================================
